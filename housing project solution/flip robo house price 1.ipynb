# %%
import pandas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\sayan\OneDrive\Desktop\fliprobo projects\Project-Housing_splitted\train.csv")
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
df=pd.DataFrame(data=df)
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
test_df=pd.read_csv(r"C:\Users\sayan\OneDrive\Desktop\fliprobo projects\Project-Housing_splitted\test.csv")
test_df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
# ...

# %%
test_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
# ...

# %%
df.drop(['PoolQC'],axis=1,inplace=True)

# %%
df.drop(['Fence'],axis=1,inplace=True)

# %%
df.drop(['MiscFeature'],axis=1,inplace=True)

# %%
df.drop(['FireplaceQu'],axis=1,inplace=True)

# %%
df.drop(['Alley'],axis=1,inplace=True)

# %%
df.drop(['MoSold'],axis=1,inplace=True)

# %%
df.drop(['BsmtQual'],axis=1,inplace=True)

# %%
df.drop(['GarageQual'],axis=1,inplace=True)

# %%
df.drop(['BsmtFinType1'],axis=1,inplace=True)

# %%
df.drop(['BsmtFinSF1'],axis=1,inplace=True)

# %%
df.drop(['BsmtFinType2'],axis=1,inplace=True)

# %%
df.drop(['BsmtFinSF2'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtCond', 'BsmtExposure',
#        'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir',
#        'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional',
#        'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars',
#        'GarageArea', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 69 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   LotShape       1168 non-null   object
#  7   LandContour    1168 non-null   object
#  8   Utilities      1168 non-null   object
#  9   LotConfig      1168 non-null   object
#  10  LandSlope      1168 non-null   object
#  11  Neighborhood   1168 non-null   object
#  12  Condition1     1168 non-null   object
#  13  Condition2     1168 non-null   object
#  14  BldgType       1168 non-null   object
#  15  HouseStyle     1168 non-null   object
#  16  OverallQual    1168 non-null   int64
# ...

# %%
import sklearn
import numpy as np
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
df['GarageCond']=imp.fit_transform(df['GarageCond'].values.reshape(-1,1))
df['GarageType']=imp.fit_transform(df['GarageType'].values.reshape(-1,1))
df['LotFrontage']=imp.fit_transform(df['LotFrontage'].values.reshape(-1,1))
df['BsmtExposure']=imp.fit_transform(df['BsmtExposure'].values.reshape(-1,1))
df['GarageFinish']=imp.fit_transform(df['GarageFinish'].values.reshape(-1,1))
df['BsmtCond']=imp.fit_transform(df['BsmtCond'].values.reshape(-1,1))
df['GarageFinish']=imp.fit_transform(df['GarageFinish'].values.reshape(-1,1))
df['GarageYrBlt']=imp.fit_transform(df['GarageYrBlt'].values.reshape(-1,1))

df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     127         120       RL         60.0     4928   Pave      IR1
# 1     889          20       RL         95.0    15865   Pave      IR1
# 2     793          60       RL         92.0     9920   Pave      IR1
# 3     110          20       RL        105.0    11751   Pave      IR1
# 4     422          20       RL         60.0    16635   Pave      IR1
# ...   ...         ...      ...          ...      ...    ...      ...
# 1163  289          20       RL         60.0     9819   Pave      IR1
# 1164  554          20       RL         67.0     8777   Pave      Reg
# 1165  196         160       RL         24.0     2280   Pave      Reg
# 1166   31          70  C (all)         50.0     8500   Pave      Reg
# 1167  617          60       RL         60.0     7861   Pave      IR1
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 69 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    1168 non-null   float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   LotShape       1168 non-null   object
#  7   LandContour    1168 non-null   object
#  8   Utilities      1168 non-null   object
#  9   LotConfig      1168 non-null   object
#  10  LandSlope      1168 non-null   object
#  11  Neighborhood   1168 non-null   object
#  12  Condition1     1168 non-null   object
#  13  Condition2     1168 non-null   object
#  14  BldgType       1168 non-null   object
#  15  HouseStyle     1168 non-null   object
#  16  OverallQual    1168 non-null   int64
# ...

# %%
df.dropna(inplace=True,axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1161 entries, 0 to 1167
# Data columns (total 69 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1161 non-null   int64
#  1   MSSubClass     1161 non-null   int64
#  2   MSZoning       1161 non-null   object
#  3   LotFrontage    1161 non-null   float64
#  4   LotArea        1161 non-null   int64
#  5   Street         1161 non-null   object
#  6   LotShape       1161 non-null   object
#  7   LandContour    1161 non-null   object
#  8   Utilities      1161 non-null   object
#  9   LotConfig      1161 non-null   object
#  10  LandSlope      1161 non-null   object
#  11  Neighborhood   1161 non-null   object
#  12  Condition1     1161 non-null   object
#  13  Condition2     1161 non-null   object
#  14  BldgType       1161 non-null   object
#  15  HouseStyle     1161 non-null   object
#  16  OverallQual    1161 non-null   int64
# ...

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
le=LabelEncoder()
list1=['SaleCondition','SaleType','PavedDrive','GarageCond','GarageFinish','GarageType','Functional','KitchenQual','CentralAir','Electrical','HeatingQC','Heating','ExterQual','ExterCond','Foundation','BsmtCond',
       'BsmtExposure','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope','Neighborhood', 'Condition1', 'Condition2', 'BldgType','MSZoning','HouseStyle']
for i in list1:
    df[i]=le.fit_transform(df[i].astype(str))
df
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0     127           0         3           66      506       1         0
# 1     889           4         3          101      354       1         0
# 2     793           9         3           98      878       1         0
# 3     110           4         3            5      174       1         0
# 4     422           4         3           66      369       1         0
# ...   ...         ...       ...          ...      ...     ...       ...
# 1163  289           4         3           66      867       1         0
# 1164  554           4         3           73      743       1         3
# 1165  196           1         3           36      421       1         3
# 1166   31          10         0           56      710       1         3
# 1167  617           9         3           66      649       1         0
#
#       LandContour  Utilities  LotConfig  ...  OpenPorchSF  EnclosedPorch  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1161 entries, 0 to 1167
# Data columns (total 69 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1161 non-null   int64
#  1   MSSubClass     1161 non-null   int32
#  2   MSZoning       1161 non-null   int32
#  3   LotFrontage    1161 non-null   int32
#  4   LotArea        1161 non-null   int32
#  5   Street         1161 non-null   int32
#  6   LotShape       1161 non-null   int32
#  7   LandContour    1161 non-null   int32
#  8   Utilities      1161 non-null   int32
#  9   LotConfig      1161 non-null   int32
#  10  LandSlope      1161 non-null   int32
#  11  Neighborhood   1161 non-null   int32
#  12  Condition1     1161 non-null   int32
#  13  Condition2     1161 non-null   int32
#  14  BldgType       1161 non-null   int32
#  15  HouseStyle     1161 non-null   int32
#  16  OverallQual    1161 non-null   int64
#  17  OverallCond    1161 non-null   int64
# ...

# %%
df.plot(kind='box',subplots=True,layout=(6,18))
# Out:
# Id                  AxesSubplot(0.125,0.772143;0.036215x0.107857)
# MSSubClass       AxesSubplot(0.168458,0.772143;0.036215x0.107857)
# MSZoning         AxesSubplot(0.211916,0.772143;0.036215x0.107857)
# LotFrontage      AxesSubplot(0.255374,0.772143;0.036215x0.107857)
# LotArea          AxesSubplot(0.298832,0.772143;0.036215x0.107857)
#                                        ...
# MiscVal          AxesSubplot(0.559579,0.383857;0.036215x0.107857)
# YrSold           AxesSubplot(0.603037,0.383857;0.036215x0.107857)
# SaleType         AxesSubplot(0.646495,0.383857;0.036215x0.107857)
# SaleCondition    AxesSubplot(0.689953,0.383857;0.036215x0.107857)
# SalePrice        AxesSubplot(0.733411,0.383857;0.036215x0.107857)
# Length: 69, dtype: object

# %%
for i in df.columns:
    plt.figure()
    sns.distplot(df[i])

# %%
df.hist(grid=False,
       figsize=(10, 6),
       bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'Id'}>,
#         <AxesSubplot:title={'center':'MSSubClass'}>,
#         <AxesSubplot:title={'center':'MSZoning'}>,
#         <AxesSubplot:title={'center':'LotFrontage'}>,
#         <AxesSubplot:title={'center':'LotArea'}>,
#         <AxesSubplot:title={'center':'Street'}>,
#         <AxesSubplot:title={'center':'LotShape'}>,
#         <AxesSubplot:title={'center':'LandContour'}>],
#        [<AxesSubplot:title={'center':'Utilities'}>,
#         <AxesSubplot:title={'center':'LotConfig'}>,
#         <AxesSubplot:title={'center':'LandSlope'}>,
#         <AxesSubplot:title={'center':'Neighborhood'}>,
#         <AxesSubplot:title={'center':'Condition1'}>,
#         <AxesSubplot:title={'center':'Condition2'}>,
#         <AxesSubplot:title={'center':'BldgType'}>,
#         <AxesSubplot:title={'center':'HouseStyle'}>],
#        [<AxesSubplot:title={'center':'OverallQual'}>,
#         <AxesSubplot:title={'center':'OverallCond'}>,
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass     MSZoning  LotFrontage      LotArea  \
# count  1161.000000  1161.000000  1161.000000  1161.000000  1161.000000
# mean    723.428079     6.269595     3.018949    67.094746   463.633075
# std     416.392272     3.541943     0.626693    20.638338   260.904781
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%     359.000000     4.000000     3.000000    63.000000   236.000000
# 50%     714.000000     5.000000     3.000000    66.000000   492.000000
# 75%    1079.000000     9.000000     3.000000    81.000000   694.000000
# max    1460.000000    14.000000     4.000000   105.000000   886.000000
#
#             Street     LotShape  LandContour  Utilities    LotConfig  ...  \
# count  1161.000000  1161.000000  1161.000000     1161.0  1161.000000  ...
# mean      0.996555     1.937123     2.772610        0.0     3.004307  ...
# std       0.058621     1.412509     0.711948        0.0     1.642900  ...
# ...

# %%
df.drop(['Utilities'],axis=1,inplace=True)
df.drop(['3SsnPorch'],axis=1,inplace=True)
df.drop(['ScreenPorch'],axis=1,inplace=True)

# %%
df
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0     127           0         3           66      506       1         0
# 1     889           4         3          101      354       1         0
# 2     793           9         3           98      878       1         0
# 3     110           4         3            5      174       1         0
# 4     422           4         3           66      369       1         0
# ...   ...         ...       ...          ...      ...     ...       ...
# 1163  289           4         3           66      867       1         0
# 1164  554           4         3           73      743       1         3
# 1165  196           1         3           36      421       1         3
# 1166   31          10         0           56      710       1         3
# 1167  617           9         3           66      649       1         0
#
#       LandContour  LotConfig  LandSlope  ...  PavedDrive  WoodDeckSF  \
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# 0     1.432988    1.770863  0.030250     0.053067  0.162455  0.058798
# 1     0.397806    0.641053  0.030250     1.643537  0.420384  0.058798
# 2     0.167155    0.771210  0.030250     1.498113  1.588877  0.058798
# 3     1.473832    0.641053  0.030250     3.010005  1.110589  0.058798
# 4     0.724216    0.641053  0.030250     0.053067  0.362867  0.058798
# ...        ...         ...       ...          ...       ...       ...
# 1163  1.043764    0.641053  0.030250     0.053067  1.546697  0.058798
# 1164  0.407071    0.641053  0.030250     0.286254  1.071223  0.058798
# 1165  1.267207    1.488411  0.030250     1.507299  0.163475  0.058798
# 1166  1.663639    1.053663  4.819346     0.537811  0.944686  0.058798
# 1167  0.255706    0.771210  0.030250     0.053067  0.710783  0.058798
#
#       LotShape  LandContour  LotConfig  LandSlope  ...  PavedDrive  \
# ...

# %%
z.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 66, dtype: int64

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   1,    1,    3, ..., 1159, 1159, 1159], dtype=int64), array([ 9, 20,  3, ..., 34, 55, 56], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0      127           0         3           66      506       1         0
# 2      793           9         3           98      878       1         0
# 5     1197           9         3           64      309       1         0
# 6      561           4         3           66      142       1         0
# 11     833           9         3           50      840       1         0
# ...    ...         ...       ...          ...      ...     ...       ...
# 1158   673           4         3           66      134       1         0
# 1161  1301           9         3           66       85       1         0
# 1163   289           4         3           66      867       1         0
# 1165   196           1         3           36      421       1         3
# 1167   617           9         3           66      649       1         0
#
#       LandContour  LotConfig  LandSlope  ...  PavedDrive  WoodDeckSF  \
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 537 entries, 0 to 1167
# Data columns (total 66 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             537 non-null    int64
#  1   MSSubClass     537 non-null    int32
#  2   MSZoning       537 non-null    int32
#  3   LotFrontage    537 non-null    int32
#  4   LotArea        537 non-null    int32
#  5   Street         537 non-null    int32
#  6   LotShape       537 non-null    int32
#  7   LandContour    537 non-null    int32
#  8   LotConfig      537 non-null    int32
#  9   LandSlope      537 non-null    int32
#  10  Neighborhood   537 non-null    int32
#  11  Condition1     537 non-null    int32
#  12  Condition2     537 non-null    int32
#  13  BldgType       537 non-null    int32
#  14  HouseStyle     537 non-null    int32
#  15  OverallQual    537 non-null    int64
#  16  OverallCond    537 non-null    int64
#  17  YearBuilt      537 non-null    int64
# ...

# %%
df_new.drop(['MiscVal'],inplace=True,axis=1)

# %%
df_new.drop(['EnclosedPorch'],inplace=True,axis=1)

# %%
df_new.drop(['PoolArea'],axis=1,inplace=True)

# %%
df_new.skew(axis=0,skipna=True)
# Out:
# Id              -0.063024
# MSSubClass       0.218269
# MSZoning         2.398961
# LotFrontage     -0.989856
# LotArea         -0.179815
#                    ...
# OpenPorchSF      1.522076
# YrSold           0.059475
# SaleType        -3.358130
# SaleCondition    1.637477
# SalePrice        0.811928
# Length: 63, dtype: float64

# %%
df_new['OverallQual'].skew()
# Out:
# -0.05821579480046335

# %%
df_new['OverallCond'].skew()
# Out:
# 0.9127908354718441

# %%
df_new['OverallCond']=np.log(df['OverallCond'])

# %%
df_new['OverallCond'].skew()
# Out:
# 0.33445875660262847

# %%
df_new['YearBuilt'].skew()
# Out:
# -0.7975365732838939

# %%
df_new['YearRemodAdd'].skew()
# Out:
# -0.7530944203577984

# %%
df_new['MasVnrArea'].skew()
# Out:
# 1.5272013844895083

# %%
df_new['MasVnrArea']=np.sqrt(df['MasVnrArea'])

# %%
df_new['MasVnrArea'].skew()
# Out:
# 0.6031898135476973

# %%
df_new['BsmtUnfSF'].skew()
# Out:
# 0.7849805543386889

# %%
df_new['BsmtUnfSF']=np.sqrt(df['BsmtUnfSF'])
df_new['BsmtUnfSF'].skew()
# Out:
# -0.1856945747379794

# %%
df_new['TotalBsmtSF'].skew()
# Out:
# 0.07041846508166272

# %%
df_new['1stFlrSF'].skew()
# Out:
# 0.47253274846336757

# %%
df_new['2ndFlrSF'].skew()
# Out:
# 0.8403926485172308

# %%
df_new['2ndFlrSF']=np.sqrt(df['2ndFlrSF'])
df_new['2ndFlrSF'].skew()
# Out:
# 0.5856118822652152

# %%
df_new['GrLivArea'].skew()
# Out:
# 0.5634202821662582

# %%
df_new['BsmtFullBath'].skew()
# Out:
# 0.13851810037399107

# %%
df_new['BsmtHalfBath'].skew()
# Out:
# 0

# %%
df_new['FullBath'].skew()
# Out:
# -0.2435933802811257

# %%
df_new['HalfBath'].skew()
# Out:
# 0.42371752578289446

# %%
df_new['BedroomAbvGr'].skew()
# Out:
# -0.5031355059742642

# %%
df_new['KitchenAbvGr'].skew()
# Out:
# 0

# %%
df_new['TotRmsAbvGrd'].skew()
# Out:
# 0.30523263374584236

# %%
df_new['Fireplaces'].skew()
# Out:
# 0.37946131030632557

# %%
df_new['GarageYrBlt'].skew()
# Out:
# -0.824382422082404

# %%
df_new['GarageCars'].skew()
# Out:
# -0.34656560001760567

# %%
df_new['GarageArea'].skew()
# Out:
# -0.0033367436603377173

# %%
df_new['WoodDeckSF'].skew()
# Out:
# 0.8158440395276374

# %%
df_new['OpenPorchSF']=np.sqrt(df['OpenPorchSF'])

# %%
df_new['OpenPorchSF'].skew()
# Out:
# 0.3264195637080446

# %%
df_new['YrSold'].skew()
# Out:
# 0.0594753417928767

# %%
df_new.skew()
# Out:
# Id              -0.063024
# MSSubClass       0.218269
# MSZoning         2.398961
# LotFrontage     -0.989856
# LotArea         -0.179815
#                    ...
# OpenPorchSF      0.326420
# YrSold           0.059475
# SaleType        -3.358130
# SaleCondition    1.637477
# SalePrice        0.811928
# Length: 63, dtype: float64

# %%
df_new.drop(['Street','LandSlope'],axis=1,inplace=True)

# %%
df_new.drop(['Condition2','RoofMatl','Heating','CentralAir','BsmtHalfBath','KitchenAbvGr'],axis=1,inplace=True)

# %%
df_new.corr()
# Out:
#                      Id  MSSubClass  MSZoning  LotFrontage   LotArea  \
# Id             1.000000    0.016334 -0.007413     0.006637  0.053197
# MSSubClass     0.016334    1.000000 -0.150593     0.204732 -0.035190
# MSZoning      -0.007413   -0.150593  1.000000    -0.239178 -0.024271
# LotFrontage    0.006637    0.204732 -0.239178     1.000000  0.017850
# LotArea        0.053197   -0.035190 -0.024271     0.017850  1.000000
# LotShape       0.031538   -0.177025  0.251914    -0.020528  0.117754
# LandContour   -0.020154    0.035237  0.031980    -0.004106  0.047670
# LotConfig      0.040410   -0.108606  0.093147     0.068250  0.160672
# Neighborhood   0.030922   -0.004433 -0.157665     0.111871 -0.015124
# Condition1    -0.024732    0.006869 -0.088897    -0.020373 -0.071952
# BldgType       0.005477   -0.589799  0.344108    -0.359388  0.005903
# HouseStyle    -0.037645    0.628505 -0.005716    -0.013108 -0.062953
# OverallQual   -0.038548    0.072225 -0.238101     0.045177 -0.156025
# ...

# %%
sns.heatmap(df_new.corr(),annot=True,linewidth=0.6)
# Out:
# <AxesSubplot:>

# %%
df_new.corr()['SalePrice'].sort_values()
# Out:
# KitchenQual     -0.645142
# ExterQual       -0.634749
# GarageFinish    -0.513812
# HeatingQC       -0.491837
# MSZoning        -0.327380
# GarageType      -0.302270
# OverallCond     -0.231281
# BsmtExposure    -0.219807
# SaleType        -0.217987
# LotArea         -0.211049
# LotShape        -0.211007
# YrSold          -0.152026
# BldgType        -0.132512
# BsmtCond        -0.121509
# LandContour     -0.119299
# LotConfig       -0.082011
# Id              -0.051032
# LowQualFinSF    -0.010694
# MasVnrType      -0.009972
# RoofStyle        0.053601
# GarageCond       0.055312
# PavedDrive       0.069002
# Electrical       0.084378
# Functional       0.107104
# Neighborhood     0.124265
# LotFrontage      0.126242
# BsmtFullBath     0.131885
# ExterCond        0.158955
# Condition1       0.176655
# MSSubClass       0.182226
# HouseStyle       0.183957
# Exterior1st      0.243777
# BsmtUnfSF        0.244325
# HalfBath         0.245531
# Exterior2nd      0.249348
# ...

# %%
df_new.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# LotShape         0
# LandContour      0
# LotConfig        0
# Neighborhood     0
# Condition1       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtCond         0
# BsmtExposure     0
# BsmtUnfSF        0
# TotalBsmtSF      0
# HeatingQC        0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# ...

# %%
x=df_new.drop(["SalePrice"],axis=1)
x
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LandContour  \
# 0      127           0         3           66      506         0            3
# 2      793           9         3           98      878         0            3
# 5     1197           9         3           64      309         0            3
# 6      561           4         3           66      142         0            3
# 11     833           9         3           50      840         0            3
# ...    ...         ...       ...          ...      ...       ...          ...
# 1158   673           4         3           66      134         0            3
# 1161  1301           9         3           66       85         0            3
# 1163   289           4         3           66      867         0            3
# 1165   196           1         3           36      421         3            3
# 1167   617           9         3           66      649         0            3
#
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x.shape
# Out:
# (537, 54)

# %%
x.shape[1]
# Out:
# 54

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif["vif factor"]=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    vif['features']=x.columns
    print(vif)

# %%
vif_calc()
# Out:
#       vif factor       features
# 0       4.592697             Id
# 1      25.257425     MSSubClass
# 2     195.670733       MSZoning
# 3      17.833251    LotFrontage
# 4       4.967379        LotArea
# 5       3.455884       LotShape
# 6      70.610954    LandContour
# 7       5.173845      LotConfig
# 8       6.227809   Neighborhood
# 9      30.575547     Condition1
# 10      4.567577       BldgType
# 11     18.493533     HouseStyle
# 12    108.419216    OverallQual
# 13    231.780117    OverallCond
# 14  62473.952199      YearBuilt
# 15  43195.149996   YearRemodAdd
# 16      5.407498      RoofStyle
# 17     69.139781    Exterior1st
# 18     59.420232    Exterior2nd
# 19     12.204069     MasVnrType
# 20      3.331691     MasVnrArea
# 21     88.025512      ExterQual
# 22     60.802486      ExterCond
# 23     26.274977     Foundation
# 24     59.098718       BsmtCond
# 25      6.512067   BsmtExposure
# 26     15.714775      BsmtUnfSF
# 27     92.196342    TotalBsmtSF
# ...

# %%
x.drop(['YearRemodAdd'],axis=1,inplace=True)

# %%
x.shape
# Out:
# (537, 53)

# %%
y=df_new.iloc[:,-1]
y
# Out:
# 0       128000
# 2       269790
# 5       219210
# 6       121500
# 11      237000
#          ...
# 1158    165000
# 1161    225000
# 1163    122000
# 1165    148500
# 1167    183200
# Name: SalePrice, Length: 537, dtype: int64

# %%
y.value_counts()
# Out:
# 135000    9
# 140000    9
# 215000    7
# 155000    6
# 120000    5
#          ..
# 293077    1
# 176500    1
# 138500    1
# 269790    1
# 183200    1
# Name: SalePrice, Length: 329, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-1.47236395, -1.67168039, -0.30715915, ..., -0.6485719 ,
#          0.32800058, -0.25284016],
#        [ 0.12130708,  0.94719524, -0.30715915, ..., -0.6485719 ,
#          0.32800058, -0.25284016],
#        [ 1.08803845,  0.94719524, -0.30715915, ..., -1.38179951,
#         -2.36110343,  2.83295907],
#        ...,
#        [-1.08471424, -0.50773567, -0.30715915, ...,  1.55111091,
#          0.32800058, -0.25284016],
#        [-1.30725389, -1.38069421, -0.30715915, ...,  0.81788331,
#          0.32800058, -0.25284016],
#        [-0.29984322,  0.94719524, -0.30715915, ..., -1.38179951,
#          0.32800058, -0.25284016]])

# %%
sc=StandardScaler()
test_df=sc.fit_transform(test_df)
test_df

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=45)

# %%
lr=LinearRegression()
knr=KNeighborsRegressor()
dtr=DecisionTreeRegressor()
svr=SVR()
rf=RandomForestRegressor(n_estimators=100,random_state=30)
model=[lr,knr,dtr,svr,rf]
for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print("predicted price:",m,predm)
    print("actual price:",m,y_test)
    print('r2_score:', r2_score(y_test,predm))
    print('error:')
    print('mean absolute error:',m,mean_absolute_error(y_test,predm))
    print('mean squared error:',m,mean_squared_error(y_test,predm))
    print('root mean squarred error:',m,np.sqrt(mean_squared_error(y_test,predm)))
# Out:
# predicted price: LinearRegression() [182384.98352585 171561.82980322 304621.57048357 240585.41718981
#  165018.8679734  121845.32231563 119345.83435089 286840.90092643
#  118925.46479152 206785.92687993 165229.17724153 202137.07799756
#  193249.16340081 306817.68116122 284510.38126923  90026.95640995
#  144237.89264856 102744.27322716 135698.1200093  186680.27896834
#  123159.75273476 166764.07720946 217182.37050935 126547.7401268
#  313245.78839439 258300.1690055  124883.76554447 280200.18999636
#  276393.25687772  93705.77383523 251889.13911164 138913.7945482
#  248370.95552754 239508.75038337 154907.58200397 179252.65975518
#  145994.91670975 203793.14576016 186343.96729245 203903.79166168
#  147601.6683136  185216.54637167 274185.65429137 206452.12795752
#  291906.24313275  74223.73925924 106418.57734164 222018.4295611
#   70948.51631185 181617.33715151 187789.71456841 185032.80174237
#  174675.26515441 145955.86966424 280839.39218583 116677.63812071
# ...

# %%
predlr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
for j in range(4,9):
    lrscore=cross_val_score(lr,x,y,cv=j)
    lrcv=lrscore.mean()
    print('at cv:-',j)
    print('crossvalidation score:',lrcv*100)
    print('r2_score:', r2_score(y_test,predlr))
    print('\n')
# Out:
# at cv:- 4
# crossvalidation score: 87.5116453312032
# r2_score: 0.9030176182448181
#
#
# at cv:- 5
# crossvalidation score: 87.53666693967196
# r2_score: 0.9030176182448181
#
#
# at cv:- 6
# crossvalidation score: 87.52731641170395
# r2_score: 0.9030176182448181
#
#
# at cv:- 7
# crossvalidation score: 87.64457254549838
# r2_score: 0.9030176182448181
#
#
# at cv:- 8
# crossvalidation score: 88.36792943298761
# r2_score: 0.9030176182448181

# %%
from sklearn. linear_model import Lasso,LassoCV,Ridge,RidgeCV

# %%
#lasso regularization
#lasscv will return the best alpha and coefficient after performing 10cross validation
lasscv=LassoCV(alphas=None,cv=10,normalize=True)
lasscv.fit(x_train,y_train)
# Out:
# LassoCV(cv=10, normalize=True)

# %%
alpha=lasscv.alpha_
alpha
# Out:
# 27.59483275641518

# %%
lasso_reg=Lasso(alpha)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=27.59483275641518)

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.9077541904247959

# %%
#using ridge regression 
#ridge cv will return best alpha
#we will  pass an array of random numbers for ridge cv to select best alpha
alphas=np.random.uniform(low=0,high=10,size=(50,))
ridgecv=RidgeCV(alphas=alphas,cv=10,normalize=True)
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([6.64170126, 8.60277812, 6.55793446, 9.98345865, 5.9370671 ,
#        0.70819397, 8.68402716, 5.4258937 , 3.6052755 , 8.9406704 ,
#        1.93075263, 9.59410191, 2.49076153, 1.28993832, 7.77016753,
#        1.42704967, 9.62784271, 1.66081168, 5.21217422, 4.82685605,
#        8.43315472, 0.44157874, 4.98149193, 8.9855185 , 2.18454257,
#        2.80377335, 6.62977429, 6.53042354, 7.51922517, 9.50997188,
#        1.31301302, 9.74892962, 9.86710109, 6.00541065, 1.44027554,
#        7.58366621, 1.23456598, 1.32311721, 7.29552593, 4.79751297,
#        7.74803416, 2.91256704, 9.30735879, 1.47785513, 6.35765487,
#        4.43018976, 8.26002604, 8.26378394, 7.12815607, 6.67842616]),
#         cv=10, normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.44157874374458284

# %%
ridge_reg=Ridge(alpha=ridgecv.alpha_)
ridge_reg.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.44157874374458284)

# %%
ridge_reg.score(x_test,y_test)
# Out:
# 0.9068395400714064

# %%
import joblib

# %%
joblib.dump(lasso_reg,'lasso_ reg huse price.obj')
# Out:
# ['lasso_ reg huse price.obj']

# %% [markdown]
# # predicting value using test dataset

# %%
test_df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
# ...

# %%
test_df.drop(['PoolQC','Fence','MiscFeature','FireplaceQu','Alley','MoSold','BsmtQual','GarageQual','BsmtFinType1','BsmtFinSF1','BsmtFinType2','BsmtFinSF2'],axis=1,inplace=True)
test_df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     337          20       RL         86.0    14157   Pave      IR1
# 1    1018         120       RL          NaN     5814   Pave      IR1
# 2     929          20       RL          NaN    11838   Pave      Reg
# 3    1148          70       RL         75.0    12000   Pave      Reg
# 4    1227          60       RL         86.0    14598   Pave      IR1
# ..    ...         ...      ...          ...      ...    ...      ...
# 287    83          20       RL         78.0    10206   Pave      Reg
# 288  1048          20       RL         57.0     9245   Pave      IR2
# 289    17          20       RL          NaN    11241   Pave      IR1
# 290   523          50       RM         50.0     5000   Pave      Reg
# 291  1379         160       RM         21.0     1953   Pave      Reg
#
#     LandContour Utilities LotConfig  ... WoodDeckSF OpenPorchSF EnclosedPorch  \
# ...

# %%
import sklearn
import numpy as np
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
test_df['GarageCond']=imp.fit_transform(test_df['GarageCond'].values.reshape(-1,1))
test_df['GarageType']=imp.fit_transform(test_df['GarageType'].values.reshape(-1,1))
test_df['LotFrontage']=imp.fit_transform(test_df['LotFrontage'].values.reshape(-1,1))
test_df['BsmtExposure']=imp.fit_transform(test_df['BsmtExposure'].values.reshape(-1,1))
test_df['GarageFinish']=imp.fit_transform(test_df['GarageFinish'].values.reshape(-1,1))
test_df['BsmtCond']=imp.fit_transform(test_df['BsmtCond'].values.reshape(-1,1))
test_df['GarageFinish']=imp.fit_transform(test_df['GarageFinish'].values.reshape(-1,1))
test_df['GarageYrBlt']=imp.fit_transform(test_df['GarageYrBlt'].values.reshape(-1,1))
test_df['MasVnrType']=imp.fit_transform(test_df['MasVnrType'].values.reshape(-1,1))
test_df['Electrical']=imp.fit_transform(test_df['Electrical'].values.reshape(-1,1))

test_df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     337          20       RL         86.0    14157   Pave      IR1
# 1    1018         120       RL         60.0     5814   Pave      IR1
# 2     929          20       RL         60.0    11838   Pave      Reg
# 3    1148          70       RL         75.0    12000   Pave      Reg
# 4    1227          60       RL         86.0    14598   Pave      IR1
# ..    ...         ...      ...          ...      ...    ...      ...
# 287    83          20       RL         78.0    10206   Pave      Reg
# 288  1048          20       RL         57.0     9245   Pave      IR2
# 289    17          20       RL         60.0    11241   Pave      IR1
# 290   523          50       RM         50.0     5000   Pave      Reg
# 291  1379         160       RM         21.0     1953   Pave      Reg
#
#     LandContour Utilities LotConfig  ... WoodDeckSF OpenPorchSF EnclosedPorch  \
# ...

# %%
import sklearn
import numpy as np
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy='median')
test_df['MasVnrArea']=imp.fit_transform(test_df['MasVnrArea'].values.reshape(-1,1))
test_df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     337          20       RL         86.0    14157   Pave      IR1
# 1    1018         120       RL         60.0     5814   Pave      IR1
# 2     929          20       RL         60.0    11838   Pave      Reg
# 3    1148          70       RL         75.0    12000   Pave      Reg
# 4    1227          60       RL         86.0    14598   Pave      IR1
# ..    ...         ...      ...          ...      ...    ...      ...
# 287    83          20       RL         78.0    10206   Pave      Reg
# 288  1048          20       RL         57.0     9245   Pave      IR2
# 289    17          20       RL         60.0    11241   Pave      IR1
# 290   523          50       RM         50.0     5000   Pave      Reg
# 291  1379         160       RM         21.0     1953   Pave      Reg
#
#     LandContour Utilities LotConfig  ... WoodDeckSF OpenPorchSF EnclosedPorch  \
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 68 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int64
#  2   MSZoning       292 non-null    object
#  3   LotFrontage    292 non-null    float64
#  4   LotArea        292 non-null    int64
#  5   Street         292 non-null    object
#  6   LotShape       292 non-null    object
#  7   LandContour    292 non-null    object
#  8   Utilities      292 non-null    object
#  9   LotConfig      292 non-null    object
#  10  LandSlope      292 non-null    object
#  11  Neighborhood   292 non-null    object
#  12  Condition1     292 non-null    object
#  13  Condition2     292 non-null    object
#  14  BldgType       292 non-null    object
#  15  HouseStyle     292 non-null    object
#  16  OverallQual    292 non-null    int64
# ...

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
le=LabelEncoder()
list1=['SaleCondition','SaleType','PavedDrive','GarageCond','GarageFinish','GarageType','Functional','KitchenQual','CentralAir','Electrical','HeatingQC','Heating','ExterQual','ExterCond','Foundation','BsmtCond',
       'BsmtExposure','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope','Neighborhood', 'Condition1', 'Condition2', 'BldgType','MSZoning','HouseStyle',]
for i in list1:
    test_df[i]=le.fit_transform(test_df[i].astype(str))
test_df
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0     337           4         2           57       82       1         0
# 1    1018           0         2           34      150       1         0
# 2     929           4         2           34       47       1         3
# 3    1148          10         2           49       52       1         3
# 4    1227           9         2           57       87       1         0
# ..    ...         ...       ...          ...      ...     ...       ...
# 287    83           4         2           52        6       1         3
# 288  1048           4         2           31      231       1         1
# 289    17           4         2           34       32       1         0
# 290   523           8         3           26      138       1         3
# 291  1379           1         3           10      111       1         3
#
#      LandContour  Utilities  LotConfig  ...  WoodDeckSF  OpenPorchSF  \
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 68 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int32
#  2   MSZoning       292 non-null    int32
#  3   LotFrontage    292 non-null    int32
#  4   LotArea        292 non-null    int32
#  5   Street         292 non-null    int32
#  6   LotShape       292 non-null    int32
#  7   LandContour    292 non-null    int32
#  8   Utilities      292 non-null    int32
#  9   LotConfig      292 non-null    int32
#  10  LandSlope      292 non-null    int32
#  11  Neighborhood   292 non-null    int32
#  12  Condition1     292 non-null    int32
#  13  Condition2     292 non-null    int32
#  14  BldgType       292 non-null    int32
#  15  HouseStyle     292 non-null    int32
#  16  OverallQual    292 non-null    int64
#  17  OverallCond    292 non-null    int64
# ...

# %%
test_df.drop(['Street','LandSlope','Condition2','RoofMatl','Heating','CentralAir','BsmtHalfBath','KitchenAbvGr','MiscVal','EnclosedPorch','PoolArea','Utilities','3SsnPorch','ScreenPorch','YearRemodAdd'],axis=1,inplace=True)
test_df
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LandContour  \
# 0     337           4         2           57       82         0            1
# 1    1018           0         2           34      150         0            3
# 2     929           4         2           34       47         3            3
# 3    1148          10         2           49       52         3            0
# 4    1227           9         2           57       87         0            3
# ..    ...         ...       ...          ...      ...       ...          ...
# 287    83           4         2           52        6         3            3
# 288  1048           4         2           31      231         1            3
# 289    17           4         2           34       32         0            3
# 290   523           8         3           26      138         3            3
# 291  1379           1         3           10      111         3            3
#
# ...

# %%
sc=StandardScaler()
test_df=sc.fit_transform(test_df)
test_df
# Out:
# array([[-0.94827766, -0.56681069, -0.28700579, ..., -0.65090813,
#          0.23029007,  0.14865423],
#        [ 0.59312021, -1.69463844, -0.28700579, ...,  0.86355541,
#         -6.49418003, -3.32390858],
#        [ 0.39167468, -0.56681069, -0.28700579, ...,  0.86355541,
#          0.23029007,  0.14865423],
#        ...,
#        [-1.67257621, -0.56681069, -0.28700579, ...,  1.62078718,
#          0.23029007,  0.14865423],
#        [-0.52727912,  0.56101706,  1.80813647, ..., -1.4081399 ,
#          0.23029007,  0.14865423],
#        [ 1.41021953, -1.4126815 ,  1.80813647, ..., -1.4081399 ,
#          0.23029007,  0.14865423]])

# %%
lasso_from_joblib=joblib.load('lasso_ reg huse price.obj')

# %%
lasso_from_joblib.predict(test_df)
# Out:
# array([302060.78211189, 180002.56832436, 252709.41685978, 213328.61926846,
#        213276.90503119,  98788.0401558 , 132881.57276569, 280047.20826366,
#        244440.98530431, 167974.07819344,  95968.15174883, 149638.24125512,
#        144914.00746403, 202391.30197174, 262056.59723224, 165045.69943758,
#        120261.17406141, 135382.02059001, 173381.16229759, 216808.44029475,
#        180610.10325481, 157330.60754212, 149456.06722554,  90516.73728664,
#        138549.18192177, 139386.8365983 , 177520.68682159, 157846.61327152,
#        169922.37885584,  94059.61509271, 187815.4440266 , 202006.09352544,
#        223245.40479594, 185152.75024647, 138169.0625534 , 165988.23595527,
#        191827.36334291, 131176.25949235, 174143.36563918, 163693.35864325,
#        122828.5240819 , 284123.43989082, 195771.96288478, 193374.88505   ,
#        144577.43559301, 158540.74757512, 121505.32338454, 130175.19649779,
# ...
